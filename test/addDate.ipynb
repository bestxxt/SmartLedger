# %%
! pip install faker
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 24.9 MB/s eta 0:00:00
# ...

# %%
import requests
import random
from datetime import datetime, timedelta
from faker import Faker

fake = Faker()

# %%
fake = Faker()

# Configuration
API_BASE = "http://localhost:3000"
LOGIN_URL = f"{API_BASE}/api/account/login"
TX_URL    = f"{API_BASE}/api/app/transactions"

# Replace with valid user credentials
CREDENTIALS = {
    "email": "admin",
    "password": "password"
}

# Start a session and login to obtain cookies
session = requests.Session()
login_resp = session.post(LOGIN_URL, json=CREDENTIALS)
if not login_resp.ok:
    raise Exception(f"Login failed ({login_resp.status_code}): {login_resp.text}")
print("Logged in successfully, cookies:", session.cookies.get_dict())
# Out:
# Logged in successfully, cookies: {'token': 'eyJhbGciOiJIUzI1NiJ9.eyJ1c2VySWQiOiI2ODExMTNiMTAyN2RiZjE5MmYwMWZkMTEiLCJ1c2VybmFtZSI6ImFkbWluIiwicm9sZSI6ImFkbWluIiwiaWF0IjoxNzQ2Mzg5MzIyLCJleHAiOjE3NDY5OTQxMjJ9.wfqZPl2xgq1NaLbryAnSkiSxwEowvrta0zVvDf_4wCQ'}

# %%
# Category definitions
CATEGORIES = {
    "Food":        ["Groceries", "Restaurants", "Cafe", "Snacks", "Takeout"],
    "Transport":   ["Bus", "Train", "Taxi", "RideShare", "Fuel", "Parking"],
    "Shopping":    ["Clothes", "Electronics", "Books", "Gifts", "Home", "Beauty"],
    "Entertainment":["Movies", "Music", "Games", "Events", "Travel"],
    "Health":      ["Medicine", "Gym", "Doctor", "Supplements"],
    "Bills":       ["Rent", "Utilities", "Internet", "Phone", "Insurance"],
    "Income":      ["Salary", "Bonus", "Interest", "Refund"],
    "Other":       ["Miscellaneous"],
}
CURRENCIES = ["USD", "CAD", "EUR", "GBP"]

# %%
# Generate and post 100 random transactions
for i in range(1, 101):
    tx_type = random.choice(["income", "expense"])
    category = random.choice(list(CATEGORIES.keys()))
    subcat = random.choice(CATEGORIES[category])
    amount = round(
        random.uniform(5, 500) if tx_type == "expense"
        else random.uniform(100, 5000),
        2
    )
    ts = datetime.now() - timedelta(
        days=random.randint(0, 365),
        hours=random.randint(0, 23),
        minutes=random.randint(0, 59),
        seconds=random.randint(0, 59),
    )

    payload = {
        "amount": amount,
        "type": tx_type,
        "category": category,
        "subcategory": subcat,
        "timestamp": ts.isoformat() + "Z",
        "note": fake.sentence(nb_words=6),
        "currency": random.choice(CURRENCIES),
        "tags": fake.words(nb=random.randint(0, 3)),
        "location": fake.city(),
    }

    resp = session.post(TX_URL, json=payload)
    if resp.ok:
        print(f"[{i:03}] ✔ {category}/{subcat} @ {ts.strftime('%Y-%m-%d %H:%M')} → {resp.status_code}")
    else:
        print(f"[{i:03}] ✘ Failed ({resp.status_code}): {resp.text}")
# Out:
# [001] ✔ Health/Medicine @ 2024-06-02 04:35 → 200
# [002] ✔ Income/Interest @ 2024-11-05 09:07 → 200
# [003] ✔ Bills/Insurance @ 2024-06-07 06:32 → 200
# [004] ✔ Bills/Insurance @ 2024-06-10 23:47 → 200
# [005] ✔ Food/Cafe @ 2025-02-12 23:08 → 200
# [006] ✔ Income/Refund @ 2025-03-05 01:31 → 200
# [007] ✔ Other/Miscellaneous @ 2025-01-15 14:16 → 200
# [008] ✔ Other/Miscellaneous @ 2025-02-04 13:58 → 200
# [009] ✔ Health/Gym @ 2024-10-01 01:25 → 200
# [010] ✔ Transport/Parking @ 2024-09-13 01:41 → 200
# [011] ✔ Entertainment/Games @ 2024-06-05 07:43 → 200
# [012] ✔ Entertainment/Travel @ 2024-11-26 00:45 → 200
# [013] ✔ Transport/Bus @ 2024-11-21 15:28 → 200
# [014] ✔ Entertainment/Music @ 2025-03-06 12:29 → 200
# [015] ✔ Food/Cafe @ 2024-08-27 09:41 → 200
# [016] ✔ Food/Cafe @ 2025-01-28 18:31 → 200
# [017] ✔ Entertainment/Movies @ 2024-05-17 16:05 → 200
# [018] ✔ Shopping/Gifts @ 2024-05-18 05:12 → 200
# [019] ✔ Health/Doctor @ 2024-06-04 15:08 → 200
# ...
